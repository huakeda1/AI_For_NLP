# %% [markdown]
# ## 1. Gensim Word2Vec
# + Python nlp 开源库，可以用来训练自己的word2vec model
# + 官网: https://radimrehurek.com/gensim/

# %% [markdown]
# ### 1.1 Word2Vec Example

# %%
from gensim.models import Word2Vec

# %%
sentences = [['cat', 'say', 'meow'], ['dog', 'say', 'woof']]
model = Word2Vec(sentences, min_count=1)

# %% [markdown]
# **Word2Vec hyperparameters**:
#     + size:词向量的维度，默认为100
#     + window: 训练时单词的窗口大小，默认为5
#     + min_count: 单词出现的最少次数，低于该值的单词会被忽略，默认为5
#     + workers:训练时使用的工作线程，默认为3
#     + sg: 使用的训练算法，CBOW(0) or skip gram(1)

# %%
model.wv.vocab
# Out:
# {'cat': <gensim.models.keyedvectors.Vocab at 0x1a1544e860>,
#  'say': <gensim.models.keyedvectors.Vocab at 0x1a1544e898>,
#  'meow': <gensim.models.keyedvectors.Vocab at 0x1a1544e8d0>,
#  'dog': <gensim.models.keyedvectors.Vocab at 0x1a1544e908>,
#  'woof': <gensim.models.keyedvectors.Vocab at 0x1a1544e940>}

# %%
model.most_similar('cat')
# Out:
# /Users/liling/anaconda3/envs/UdaCourse/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('meow', 0.061344344168901443),
#  ('dog', 0.03607504069805145),
#  ('woof', -0.011934641748666763),
#  ('say', -0.05083806812763214)]

# %%
model.wv['dog']
# Out:
# array([-0.00324721, -0.00372931, -0.00132748, -0.0012167 ,  0.00421101,
#         0.0016716 , -0.00329486,  0.0021082 ,  0.00307677,  0.00447989,
#         0.00136921, -0.00494903,  0.00495272, -0.0016848 ,  0.00385503,
#        -0.00326887, -0.00105373,  0.00193478, -0.0004452 , -0.00385089,
#         0.00210099,  0.00366337,  0.00010262, -0.00441987,  0.00183587,
#        -0.00135071, -0.00198604,  0.00108519, -0.00120252, -0.00399885,
#         0.00490881,  0.00253169, -0.00297924, -0.00365355,  0.00378577,
#         0.00476437, -0.00082827, -0.00486974,  0.00374594, -0.00163786,
#         0.00125674,  0.00491777,  0.00112151,  0.00118815,  0.00050925,
#         0.00028776,  0.00301926,  0.00326783,  0.00044682,  0.00361566,
#         0.00413984,  0.00042816, -0.00342651,  0.00253967,  0.00255286,
#        -0.00066174,  0.00186746,  0.00250534, -0.00108073,  0.00447955,
#        -0.00357158,  0.00496709, -0.00258402,  0.00299036, -0.00422876,
#         0.00032904,  0.0024151 ,  0.00031464,  0.00438139, -0.00258518,
#         0.00454957,  0.00355928, -0.00379194,  0.0014805 , -0.0022112 ,
#        -0.00034366,  0.00416533,  0.00288865,  0.0042723 , -0.00115841,
#         0.00098736, -0.00218574, -0.00133491,  0.00340201, -0.00148544,
#         0.0010267 , -0.00321012,  0.00126703,  0.00274457, -0.00306997,
#         0.00452989,  0.00258577, -0.00143926,  0.00384102,  0.00355207,
#         0.00414326,  0.00190825, -0.00086235, -0.00132998, -0.00496136],
#       dtype=float32)

# %% [markdown]
# ### 1.2 使用新闻语料库训练Word2Vec

# %%
database = '/Users/liling/Documents/00TrelloNLP/DATA/news_data.csv'

# %%
import pandas as pd

# %%
content = pd.read_csv(database, encoding='gb18030')

# %%
content.head()
# Out:
#       id      author                  source  \
# 0  89617         NaN  快科技@http://www.kkj.cn/
# 1  89616         NaN  快科技@http://www.kkj.cn/
# 2  89615         NaN  快科技@http://www.kkj.cn/
# 3  89614         NaN                     新华社
# 4  89613  胡淑丽_MN7479                   深圳大件事
#
#                                              content  \
# 0  此外，自本周（6月12日）起，除小米手机6等15款机型外，其余机型已暂停更新发布（含开发版/...
# 1  骁龙835作为唯一通过Windows 10桌面平台认证的ARM处理器，高通强调，不会因为只考...
# 2  此前的一加3T搭载的是3400mAh电池，DashCharge快充规格为5V/4A。\r\n...
# 3    这是6月18日在葡萄牙中部大佩德罗冈地区拍摄的被森林大火烧毁的汽车。新华社记者张立云摄\r\n
# 4  （原标题：44岁女子跑深圳约会网友被拒，暴雨中裸身奔走……）\r\n@深圳交警微博称：昨日清...
#
#                                              feature  \
# 0  {"type":"科技","site":"cnbeta","commentNum":"37"...
# 1  {"type":"科技","site":"cnbeta","commentNum":"15"...
# 2  {"type":"科技","site":"cnbeta","commentNum":"18"...
# 3  {"type":"国际新闻","site":"环球","commentNum":"0","j...
# 4  {"type":"新闻","site":"网易热门","commentNum":"978",...
#
#                            title  \
# 0           小米MIUI 9首批机型曝光：共计15款
# 1     骁龙835在Windows 10上的性能表现有望改善
# 2      一加手机5细节曝光：3300mAh、充半小时用1天
# 3  葡森林火灾造成至少62人死亡 政府宣布进入紧急状态（组图）
# 4       44岁女子约网友被拒暴雨中裸奔 交警为其披衣相随
#
#                                                  url
# 0     http://www.cnbeta.com/articles/tech/623597.htm
# 1     http://www.cnbeta.com/articles/tech/623599.htm
# 2     http://www.cnbeta.com/articles/tech/623601.htm
# 3  http://world.huanqiu.com/hot/2017-06/10866126....
# 4  http://news.163.com/17/0618/00/CN617P3Q0001875...

# %%
# 使用新闻内容字段作为训练语料
samples = content['content'][:100].tolist()

# %%
import jieba

# %%
def cut(string):
    return ' '.join(jieba.cut(string))

# %%
cut('这是一个测试')
# Out:
# Building prefix dict from /Users/liling/anaconda3/envs/UdaCourse/lib/python3.6/site-packages/jieba/dict.txt ...
# Dumping model to file cache /var/folders/jh/b14_bh2n1753x9hvqr8zhtg40000gn/T/jieba.cache
# Loading model cost 1.6531429290771484 seconds.
# Prefix dict has been built succesfully.
# '这是 一个 测试'

# %%
# 将训练语料分词后写入文件
with open('mini_samples.txt', 'w') as f:
    for s in samples:
        f.write(cut(s) + '\n')

# %%
from gensim.models.word2vec import LineSentence

# %%
sentences = LineSentence('mini_samples.txt')

# %%
model = Word2Vec(sentences, min_count=1)

# %%
model.wv['小米']
# Out:
# array([ 0.02697092, -0.01238676,  0.00570923,  0.01853787,  0.02806742,
#        -0.01462012,  0.0350339 , -0.00179451,  0.01759951, -0.02614262,
#        -0.02788118,  0.03073505,  0.0157554 ,  0.04029954,  0.02168221,
#         0.00470081, -0.00819971,  0.01049386, -0.00412498,  0.02106893,
#         0.00220568, -0.01992517,  0.01322071, -0.00595903, -0.00906719,
#         0.00678828,  0.0349687 ,  0.01869414, -0.01228004,  0.05206617,
#        -0.02875679,  0.02785175,  0.01187365, -0.01059754, -0.01204202,
#        -0.02703042,  0.00813641, -0.01283405, -0.00111703,  0.0076571 ,
#        -0.02203112,  0.01463147, -0.00241408, -0.00466241, -0.00071005,
#        -0.02957297, -0.02144731,  0.01862562, -0.02289989, -0.00208864,
#         0.0214048 ,  0.00385532,  0.02306326,  0.01654031,  0.01121977,
#        -0.03119729,  0.00314351, -0.0039577 ,  0.00575926, -0.00233956,
#        -0.00728019,  0.02484645,  0.00684136,  0.02297481, -0.01400474,
#         0.02863117,  0.00999623, -0.01596094,  0.02313304,  0.02366457,
#         0.00254867, -0.00473007,  0.02637104,  0.02219513,  0.02370626,
#        -0.00383604,  0.01043723,  0.02478944,  0.03440288, -0.01091703,
#         0.04323829, -0.00464848, -0.00497828,  0.03287397,  0.00977488,
#        -0.02353952,  0.0160344 , -0.00788875, -0.0098294 , -0.0175832 ,
#         0.00285948, -0.02572073, -0.02437151,  0.0204123 , -0.02126979,
#        -0.00731379, -0.02106087, -0.0035867 ,  0.01291797,  0.02290538],
#       dtype=float32)

# %%
model.most_similar('小米')
# Out:
# /Users/liling/anaconda3/envs/UdaCourse/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('变化', 0.9910062551498413),
#  ('国内', 0.9909408092498779),
#  ('实施', 0.9909210205078125),
#  ('人们', 0.9909133911132812),
#  ('人民币', 0.9909095764160156),
#  ('请', 0.9908913969993591),
#  ('投资者', 0.9908566474914551),
#  ('完全', 0.9908537268638611),
#  ('车辆', 0.9908179640769958),
#  ('学园', 0.9908175468444824)]

# %%
model.wv.vocab
# Out:
# {'此外': <gensim.models.keyedvectors.Vocab at 0x1a236971d0>,
#  '，': <gensim.models.keyedvectors.Vocab at 0x1a23697080>,
#  '自': <gensim.models.keyedvectors.Vocab at 0x1a236970b8>,
#  '本周': <gensim.models.keyedvectors.Vocab at 0x1a23697320>,
#  '（': <gensim.models.keyedvectors.Vocab at 0x1a23697358>,
#  '6': <gensim.models.keyedvectors.Vocab at 0x1a23697390>,
#  '月': <gensim.models.keyedvectors.Vocab at 0x1a236973c8>,
#  '12': <gensim.models.keyedvectors.Vocab at 0x1a23697400>,
#  '日': <gensim.models.keyedvectors.Vocab at 0x1a23697438>,
#  '）': <gensim.models.keyedvectors.Vocab at 0x1a23697470>,
#  '起': <gensim.models.keyedvectors.Vocab at 0x1a236974a8>,
#  '除': <gensim.models.keyedvectors.Vocab at 0x1a236974e0>,
#  '小米': <gensim.models.keyedvectors.Vocab at 0x1a23697518>,
#  '手机': <gensim.models.keyedvectors.Vocab at 0x1a23697550>,
#  '等': <gensim.models.keyedvectors.Vocab at 0x1a23697588>,
#  '15': <gensim.models.keyedvectors.Vocab at 0x1a236975c0>,
#  '款': <gensim.models.keyedvectors.Vocab at 0x1a236975f8>,
#  '机型': <gensim.models.keyedvectors.Vocab at 0x1a23697630>,
#  '外': <gensim.models.keyedvectors.Vocab at 0x1a23697668>,
#  '其余': <gensim.models.keyedvectors.Vocab at 0x1a236976a0>,
#  '已': <gensim.models.keyedvectors.Vocab at 0x1a236976d8>,
#  '暂停': <gensim.models.keyedvectors.Vocab at 0x1a23697710>,
#  '更新': <gensim.models.keyedvectors.Vocab at 0x1a23697748>,
#  '发布': <gensim.models.keyedvectors.Vocab at 0x1a23697780>,
#  '含': <gensim.models.keyedvectors.Vocab at 0x1a236977b8>,
#  '开发': <gensim.models.keyedvectors.Vocab at 0x1a236977f0>,
#  '版': <gensim.models.keyedvectors.Vocab at 0x1a23697828>,
#  '/': <gensim.models.keyedvectors.Vocab at 0x1a23697860>,
#  '体验版': <gensim.models.keyedvectors.Vocab at 0x1a23697898>,
#  '内测': <gensim.models.keyedvectors.Vocab at 0x1a236978d0>,
#  '稳定版': <gensim.models.keyedvectors.Vocab at 0x1a23697908>,
#  '暂不受': <gensim.models.keyedvectors.Vocab at 0x1a23697940>,
#  '影响': <gensim.models.keyedvectors.Vocab at 0x1a23697978>,
#  '以': <gensim.models.keyedvectors.Vocab at 0x1a236979b0>,
#  '确保': <gensim.models.keyedvectors.Vocab at 0x1a236979e8>,
#  '工程师': <gensim.models.keyedvectors.Vocab at 0x1a23697a20>,
#  '可以': <gensim.models.keyedvectors.Vocab at 0x1a23697a58>,
#  '集中': <gensim.models.keyedvectors.Vocab at 0x1a23697a90>,
#  '全部': <gensim.models.keyedvectors.Vocab at 0x1a23697ac8>,
#  '精力': <gensim.models.keyedvectors.Vocab at 0x1a23697b00>,
#  '进行': <gensim.models.keyedvectors.Vocab at 0x1a23697b38>,
#  '系统优化': <gensim.models.keyedvectors.Vocab at 0x1a23697b70>,
#  '工作': <gensim.models.keyedvectors.Vocab at 0x1a23697ba8>,
#  '。': <gensim.models.keyedvectors.Vocab at 0x1a23697be0>,
#  '有人': <gensim.models.keyedvectors.Vocab at 0x1a23697c18>,
#  '猜测': <gensim.models.keyedvectors.Vocab at 0x1a23697c50>,
#  '这': <gensim.models.keyedvectors.Vocab at 0x1a23697c88>,
#  '也': <gensim.models.keyedvectors.Vocab at 0x1a23697cc0>,
#  '是': <gensim.models.keyedvectors.Vocab at 0x1a23697cf8>,
#  '将': <gensim.models.keyedvectors.Vocab at 0x1a23697d30>,
#  '主要': <gensim.models.keyedvectors.Vocab at 0x1a23697d68>,
#  '用到': <gensim.models.keyedvectors.Vocab at 0x1a23697da0>,
#  'MIUI': <gensim.models.keyedvectors.Vocab at 0x1a23697dd8>,
#  '9': <gensim.models.keyedvectors.Vocab at 0x1a23697e10>,
#  '的': <gensim.models.keyedvectors.Vocab at 0x1a23697e48>,
#  '研发': <gensim.models.keyedvectors.Vocab at 0x1a23697e80>,
#  '之中': <gensim.models.keyedvectors.Vocab at 0x1a23697eb8>,
#  '8': <gensim.models.keyedvectors.Vocab at 0x1a23697ef0>,
#  '去年': <gensim.models.keyedvectors.Vocab at 0x1a23697f28>,
#  '5': <gensim.models.keyedvectors.Vocab at 0x1a23697f60>,
#  '距今已有': <gensim.models.keyedvectors.Vocab at 0x1a23697f98>,
#  '一年': <gensim.models.keyedvectors.Vocab at 0x1a23697fd0>,
#  '有余': <gensim.models.keyedvectors.Vocab at 0x1a236bc048>,
#  '时候': <gensim.models.keyedvectors.Vocab at 0x1a236bc080>,
#  '更新换代': <gensim.models.keyedvectors.Vocab at 0x1a236bc0b8>,
#  '了': <gensim.models.keyedvectors.Vocab at 0x1a236bc0f0>,
#  '当然': <gensim.models.keyedvectors.Vocab at 0x1a236bc128>,
#  '关于': <gensim.models.keyedvectors.Vocab at 0x1a236bc160>,
#  '确切': <gensim.models.keyedvectors.Vocab at 0x1a236bc198>,
#  '信息': <gensim.models.keyedvectors.Vocab at 0x1a236bc1d0>,
#  '我们': <gensim.models.keyedvectors.Vocab at 0x1a236bc208>,
#  '还是': <gensim.models.keyedvectors.Vocab at 0x1a236bc240>,
#  '等待': <gensim.models.keyedvectors.Vocab at 0x1a236bc278>,
#  '官方消息': <gensim.models.keyedvectors.Vocab at 0x1a236bc2b0>,
#  '骁龙': <gensim.models.keyedvectors.Vocab at 0x1a236bc2e8>,
#  '835': <gensim.models.keyedvectors.Vocab at 0x1a236bc320>,
#  '作为': <gensim.models.keyedvectors.Vocab at 0x1a236bc358>,
#  '唯一': <gensim.models.keyedvectors.Vocab at 0x1a236bc390>,
#  '通过': <gensim.models.keyedvectors.Vocab at 0x1a236bc3c8>,
#  'Windows': <gensim.models.keyedvectors.Vocab at 0x1a236bc400>,
#  '10': <gensim.models.keyedvectors.Vocab at 0x1a236bc438>,
#  '桌面': <gensim.models.keyedvectors.Vocab at 0x1a236bc470>,
#  '平台': <gensim.models.keyedvectors.Vocab at 0x1a236bc4a8>,
#  '认证': <gensim.models.keyedvectors.Vocab at 0x1a236bc4e0>,
#  'ARM': <gensim.models.keyedvectors.Vocab at 0x1a236bc518>,
#  '处理器': <gensim.models.keyedvectors.Vocab at 0x1a236bc550>,
#  '高通': <gensim.models.keyedvectors.Vocab at 0x1a236bc588>,
#  '强调': <gensim.models.keyedvectors.Vocab at 0x1a236bc5c0>,
#  '不会': <gensim.models.keyedvectors.Vocab at 0x1a236bc5f8>,
#  '因为': <gensim.models.keyedvectors.Vocab at 0x1a236bc630>,
#  '只': <gensim.models.keyedvectors.Vocab at 0x1a236bc668>,
#  '考虑': <gensim.models.keyedvectors.Vocab at 0x1a236bc6a0>,
#  '性能': <gensim.models.keyedvectors.Vocab at 0x1a236bc6d8>,
#  '而': <gensim.models.keyedvectors.Vocab at 0x1a236bc710>,
#  '去': <gensim.models.keyedvectors.Vocab at 0x1a236bc748>,
#  '屏蔽掉': <gensim.models.keyedvectors.Vocab at 0x1a236bc780>,
#  '小': <gensim.models.keyedvectors.Vocab at 0x1a236bc7b8>,
#  '核心': <gensim.models.keyedvectors.Vocab at 0x1a236bc7f0>,
#  '相反': <gensim.models.keyedvectors.Vocab at 0x1a236bc828>,
#  '他们': <gensim.models.keyedvectors.Vocab at 0x1a236bc860>,
#  '正': <gensim.models.keyedvectors.Vocab at 0x1a236bc898>,
#  '联手': <gensim.models.keyedvectors.Vocab at 0x1a236bc8d0>,
#  '微软': <gensim.models.keyedvectors.Vocab at 0x1a236bc908>,
#  '找到': <gensim.models.keyedvectors.Vocab at 0x1a236bc940>,
#  '一种': <gensim.models.keyedvectors.Vocab at 0x1a236bc978>,
#  '适合': <gensim.models.keyedvectors.Vocab at 0x1a236bc9b0>,
#  '、': <gensim.models.keyedvectors.Vocab at 0x1a236bc9e8>,
#  '兼顾': <gensim.models.keyedvectors.Vocab at 0x1a236bca20>,
#  '和': <gensim.models.keyedvectors.Vocab at 0x1a236bca58>,
#  '功耗': <gensim.models.keyedvectors.Vocab at 0x1a236bca90>,
#  '完美': <gensim.models.keyedvectors.Vocab at 0x1a236bcac8>,
#  '方案': <gensim.models.keyedvectors.Vocab at 0x1a236bcb00>,
#  '报道': <gensim.models.keyedvectors.Vocab at 0x1a236bcb38>,
#  '称': <gensim.models.keyedvectors.Vocab at 0x1a236bcb70>,
#  '已经': <gensim.models.keyedvectors.Vocab at 0x1a236bcba8>,
#  '拿到': <gensim.models.keyedvectors.Vocab at 0x1a236bcbe0>,
#  '一些': <gensim.models.keyedvectors.Vocab at 0x1a236bcc18>,
#  '新': <gensim.models.keyedvectors.Vocab at 0x1a236bcc50>,
#  '源码': <gensim.models.keyedvectors.Vocab at 0x1a236bcc88>,
#  '以便': <gensim.models.keyedvectors.Vocab at 0x1a236bccc0>,
#  '更好': <gensim.models.keyedvectors.Vocab at 0x1a236bccf8>,
#  '地': <gensim.models.keyedvectors.Vocab at 0x1a236bcd30>,
#  '理解': <gensim.models.keyedvectors.Vocab at 0x1a236bcd68>,
#  'big': <gensim.models.keyedvectors.Vocab at 0x1a236bcda0>,
#  '.': <gensim.models.keyedvectors.Vocab at 0x1a236bcdd8>,
#  'little': <gensim.models.keyedvectors.Vocab at 0x1a236bce10>,
#  '架构': <gensim.models.keyedvectors.Vocab at 0x1a236bce48>,
#  '资料': <gensim.models.keyedvectors.Vocab at 0x1a236bce80>,
#  '显示': <gensim.models.keyedvectors.Vocab at 0x1a236bceb8>,
#  '一款': <gensim.models.keyedvectors.Vocab at 0x1a236bcef0>,
#  '集成': <gensim.models.keyedvectors.Vocab at 0x1a236bcf28>,
#  'CPU': <gensim.models.keyedvectors.Vocab at 0x1a236bcf60>,
#  'GPU': <gensim.models.keyedvectors.Vocab at 0x1a236bcf98>,
#  '基带': <gensim.models.keyedvectors.Vocab at 0x1a236bcfd0>,
#  '蓝牙': <gensim.models.keyedvectors.Vocab at 0x1a228ad048>,
#  'Wi': <gensim.models.keyedvectors.Vocab at 0x1a228ad080>,
#  '-': <gensim.models.keyedvectors.Vocab at 0x1a228ad0b8>,
#  'Fi': <gensim.models.keyedvectors.Vocab at 0x1a228ad0f0>,
#  'SoC': <gensim.models.keyedvectors.Vocab at 0x1a228ad128>,
#  '比': <gensim.models.keyedvectors.Vocab at 0x1a228ad160>,
#  '传统': <gensim.models.keyedvectors.Vocab at 0x1a228ad198>,
#  'Wintel': <gensim.models.keyedvectors.Vocab at 0x1a228ad1d0>,
#  '节省': <gensim.models.keyedvectors.Vocab at 0x1a228ad208>,
#  '至少': <gensim.models.keyedvectors.Vocab at 0x1a228ad240>,
#  '30': <gensim.models.keyedvectors.Vocab at 0x1a228ad278>,
#  '%': <gensim.models.keyedvectors.Vocab at 0x1a228ad2b0>,
#  'PCB': <gensim.models.keyedvectors.Vocab at 0x1a228ad2e8>,
#  '空间': <gensim.models.keyedvectors.Vocab at 0x1a228ad320>,
#  '按计划': <gensim.models.keyedvectors.Vocab at 0x1a228ad358>,
#  '今年': <gensim.models.keyedvectors.Vocab at 0x1a228ad390>,
#  'Q4': <gensim.models.keyedvectors.Vocab at 0x1a228ad3c8>,
#  '华硕': <gensim.models.keyedvectors.Vocab at 0x1a228ad400>,
#  '惠普': <gensim.models.keyedvectors.Vocab at 0x1a228ad438>,
#  '联想': <gensim.models.keyedvectors.Vocab at 0x1a228ad470>,
#  '首发': <gensim.models.keyedvectors.Vocab at 0x1a228ad4a8>,
#  'Win10': <gensim.models.keyedvectors.Vocab at 0x1a228ad4e0>,
#  '电脑': <gensim.models.keyedvectors.Vocab at 0x1a228ad518>,
#  '预计': <gensim.models.keyedvectors.Vocab at 0x1a228ad550>,
#  '均': <gensim.models.keyedvectors.Vocab at 0x1a228ad588>,
#  '二合一': <gensim.models.keyedvectors.Vocab at 0x1a228ad5c0>,
#  '形态': <gensim.models.keyedvectors.Vocab at 0x1a228ad5f8>,
#  '产品': <gensim.models.keyedvectors.Vocab at 0x1a228ad630>,
#  '只是': <gensim.models.keyedvectors.Vocab at 0x1a228ad668>,
#  '个': <gensim.models.keyedvectors.Vocab at 0x1a228ad6a0>,
#  '开始': <gensim.models.keyedvectors.Vocab at 0x1a228ad6d8>,
#  '未来': <gensim.models.keyedvectors.Vocab at 0x1a228ad710>,
#  '也许': <gensim.models.keyedvectors.Vocab at 0x1a228ad748>,
#  '还': <gensim.models.keyedvectors.Vocab at 0x1a228ad780>,
#  '能': <gensim.models.keyedvectors.Vocab at 0x1a228ad7b8>,
#  '见到': <gensim.models.keyedvectors.Vocab at 0x1a228ad7f0>,
#  '三星': <gensim.models.keyedvectors.Vocab at 0x1a228ad828>,
#  'Exynos': <gensim.models.keyedvectors.Vocab at 0x1a228ad860>,
#  '联发科': <gensim.models.keyedvectors.Vocab at 0x1a228ad898>,
#  '华为': <gensim.models.keyedvectors.Vocab at 0x1a228ad8d0>,
#  '麒麟': <gensim.models.keyedvectors.Vocab at 0x1a228ad908>,
#  '澎湃': <gensim.models.keyedvectors.Vocab at 0x1a228ad940>,
#  '进入': <gensim.models.keyedvectors.Vocab at 0x1a228ad978>,
#  '此前': <gensim.models.keyedvectors.Vocab at 0x1a228ad9b0>,
#  '一加': <gensim.models.keyedvectors.Vocab at 0x1a228ad9e8>,
#  '3T': <gensim.models.keyedvectors.Vocab at 0x1a228ada20>,
#  '搭载': <gensim.models.keyedvectors.Vocab at 0x1a228ada58>,
#  '3400mAh': <gensim.models.keyedvectors.Vocab at 0x1a228ada90>,
#  '电池': <gensim.models.keyedvectors.Vocab at 0x1a228adac8>,
#  'DashCharge': <gensim.models.keyedvectors.Vocab at 0x1a228adb00>,
#  '快充': <gensim.models.keyedvectors.Vocab at 0x1a228adb38>,
#  '规格': <gensim.models.keyedvectors.Vocab at 0x1a228adb70>,
#  '为': <gensim.models.keyedvectors.Vocab at 0x1a228adba8>,
#  '5V': <gensim.models.keyedvectors.Vocab at 0x1a228adbe0>,
#  '4A': <gensim.models.keyedvectors.Vocab at 0x1a228adc18>,
#  '至于': <gensim.models.keyedvectors.Vocab at 0x1a228adc50>,
#  '缩水': <gensim.models.keyedvectors.Vocab at 0x1a228adc88>,
#  '可能': <gensim.models.keyedvectors.Vocab at 0x1a228adcc0>,
#  '与': <gensim.models.keyedvectors.Vocab at 0x1a228adcf8>,
#  '刘作': <gensim.models.keyedvectors.Vocab at 0x1a228add30>,
#  '虎': <gensim.models.keyedvectors.Vocab at 0x1a228add68>,
#  '所说': <gensim.models.keyedvectors.Vocab at 0x1a228adda0>,
#  '要': <gensim.models.keyedvectors.Vocab at 0x1a228addd8>,
#  '做': <gensim.models.keyedvectors.Vocab at 0x1a228ade10>,
#  '市面': <gensim.models.keyedvectors.Vocab at 0x1a228ade48>,
#  '最': <gensim.models.keyedvectors.Vocab at 0x1a228ade80>,
#  '轻薄': <gensim.models.keyedvectors.Vocab at 0x1a228adeb8>,
#  '大屏': <gensim.models.keyedvectors.Vocab at 0x1a228adef0>,
#  '旗舰': <gensim.models.keyedvectors.Vocab at 0x1a228adf28>,
#  '设定': <gensim.models.keyedvectors.Vocab at 0x1a228adf60>,
#  '有关': <gensim.models.keyedvectors.Vocab at 0x1a228adf98>,
#  '按照': <gensim.models.keyedvectors.Vocab at 0x1a228adfd0>,
#  '目前': <gensim.models.keyedvectors.Vocab at 0x1a228a7048>,
#  '掌握': <gensim.models.keyedvectors.Vocab at 0x1a228a7080>,
#  '拥有': <gensim.models.keyedvectors.Vocab at 0x1a228a70b8>,
#  '5.5': <gensim.models.keyedvectors.Vocab at 0x1a228a70f0>,
#  '寸': <gensim.models.keyedvectors.Vocab at 0x1a228a7128>,
#  '1080P': <gensim.models.keyedvectors.Vocab at 0x1a228a7160>,
#  'AMOLED': <gensim.models.keyedvectors.Vocab at 0x1a228a7198>,
#  '显示屏': <gensim.models.keyedvectors.Vocab at 0x1a228a71d0>,
#  '6G': <gensim.models.keyedvectors.Vocab at 0x1a228a7208>,
#  '8GB': <gensim.models.keyedvectors.Vocab at 0x1a228a7240>,
#  'RAM': <gensim.models.keyedvectors.Vocab at 0x1a228a7278>,
#  '64GB': <gensim.models.keyedvectors.Vocab at 0x1a228a72b0>,
#  '128GB': <gensim.models.keyedvectors.Vocab at 0x1a228a72e8>,
#  'ROM': <gensim.models.keyedvectors.Vocab at 0x1a228a7320>,
#  '双': <gensim.models.keyedvectors.Vocab at 0x1a228a7358>,
#  '1600': <gensim.models.keyedvectors.Vocab at 0x1a228a7390>,
#  '万': <gensim.models.keyedvectors.Vocab at 0x1a228a73c8>,
#  '摄像头': <gensim.models.keyedvectors.Vocab at 0x1a228a7400>,
#  '备货': <gensim.models.keyedvectors.Vocab at 0x1a228a7438>,
#  '量': <gensim.models.keyedvectors.Vocab at 0x1a228a7470>,
#  '“': <gensim.models.keyedvectors.Vocab at 0x1a228a74a8>,
#  '惊喜': <gensim.models.keyedvectors.Vocab at 0x1a228a74e0>,
#  '”': <gensim.models.keyedvectors.Vocab at 0x1a228a7518>,
#  '根据': <gensim.models.keyedvectors.Vocab at 0x1a228a7550>,
#  '京东': <gensim.models.keyedvectors.Vocab at 0x1a228a7588>,
#  '泄露': <gensim.models.keyedvectors.Vocab at 0x1a228a75c0>,
#  '售价': <gensim.models.keyedvectors.Vocab at 0x1a228a75f8>,
#  'xx99': <gensim.models.keyedvectors.Vocab at 0x1a228a7630>,
#  '元': <gensim.models.keyedvectors.Vocab at 0x1a228a7668>,
#  '应该': <gensim.models.keyedvectors.Vocab at 0x1a228a76a0>,
#  '在': <gensim.models.keyedvectors.Vocab at 0x1a228a76d8>,
#  '2799': <gensim.models.keyedvectors.Vocab at 0x1a228a7710>,
#  '2899': <gensim.models.keyedvectors.Vocab at 0x1a228a7748>,
#  '2999': <gensim.models.keyedvectors.Vocab at 0x1a228a7780>,
#  '中': <gensim.models.keyedvectors.Vocab at 0x1a228a77b8>,
#  '某个': <gensim.models.keyedvectors.Vocab at 0x1a228a77f0>,
#  '这是': <gensim.models.keyedvectors.Vocab at 0x1a228a7828>,
#  '18': <gensim.models.keyedvectors.Vocab at 0x1a228a7860>,
#  '葡萄牙': <gensim.models.keyedvectors.Vocab at 0x1a228a7898>,
#  '中部': <gensim.models.keyedvectors.Vocab at 0x1a228a78d0>,
#  '大': <gensim.models.keyedvectors.Vocab at 0x1a228a7908>,
#  '佩德罗': <gensim.models.keyedvectors.Vocab at 0x1a228a7940>,
#  '冈': <gensim.models.keyedvectors.Vocab at 0x1a228a7978>,
#  '地区': <gensim.models.keyedvectors.Vocab at 0x1a228a79b0>,
#  '拍摄': <gensim.models.keyedvectors.Vocab at 0x1a228a79e8>,
#  '被': <gensim.models.keyedvectors.Vocab at 0x1a228a7a20>,
#  '森林': <gensim.models.keyedvectors.Vocab at 0x1a228a7a58>,
#  '大火': <gensim.models.keyedvectors.Vocab at 0x1a228a7a90>,
#  '烧毁': <gensim.models.keyedvectors.Vocab at 0x1a228a7ac8>,
#  '汽车': <gensim.models.keyedvectors.Vocab at 0x1a228a7b00>,
#  '新华社': <gensim.models.keyedvectors.Vocab at 0x1a228a7b38>,
#  '记者': <gensim.models.keyedvectors.Vocab at 0x1a228a7b70>,
#  '张立': <gensim.models.keyedvectors.Vocab at 0x1a228a7ba8>,
#  '云摄': <gensim.models.keyedvectors.Vocab at 0x1a228a7be0>,
#  '原': <gensim.models.keyedvectors.Vocab at 0x1a228a7c18>,
#  '标题': <gensim.models.keyedvectors.Vocab at 0x1a228a7c50>,
#  '：': <gensim.models.keyedvectors.Vocab at 0x1a228a7c88>,
#  '44': <gensim.models.keyedvectors.Vocab at 0x1a228a7cc0>,
#  '岁': <gensim.models.keyedvectors.Vocab at 0x1a228a7cf8>,
#  '女子': <gensim.models.keyedvectors.Vocab at 0x1a228a7d30>,
#  '跑': <gensim.models.keyedvectors.Vocab at 0x1a228a7d68>,
#  '深圳': <gensim.models.keyedvectors.Vocab at 0x1a228a7da0>,
#  '约会': <gensim.models.keyedvectors.Vocab at 0x1a228a7dd8>,
#  '网友': <gensim.models.keyedvectors.Vocab at 0x1a228a7e10>,
#  '拒': <gensim.models.keyedvectors.Vocab at 0x1a228a7e48>,
#  '暴雨': <gensim.models.keyedvectors.Vocab at 0x1a228a7e80>,
#  '裸身': <gensim.models.keyedvectors.Vocab at 0x1a228a7eb8>,
#  '奔走': <gensim.models.keyedvectors.Vocab at 0x1a228a7ef0>,
#  '…': <gensim.models.keyedvectors.Vocab at 0x1a228a7f28>,
#  '@': <gensim.models.keyedvectors.Vocab at 0x1a228a7f60>,
#  '交警': <gensim.models.keyedvectors.Vocab at 0x1a228a7f98>,
#  '微博称': <gensim.models.keyedvectors.Vocab at 0x1a228a7fd0>,
#  '昨日': <gensim.models.keyedvectors.Vocab at 0x1a22896048>,
#  '清晨': <gensim.models.keyedvectors.Vocab at 0x1a22896080>,
#  '发现': <gensim.models.keyedvectors.Vocab at 0x1a228960b8>,
#  '有': <gensim.models.keyedvectors.Vocab at 0x1a228960f0>,
#  '一': <gensim.models.keyedvectors.Vocab at 0x1a22896128>,
#  '赤裸': <gensim.models.keyedvectors.Vocab at 0x1a22896160>,
#  '上身': <gensim.models.keyedvectors.Vocab at 0x1a22896198>,
#  '行走': <gensim.models.keyedvectors.Vocab at 0x1a228961d0>,
#  '南坪': <gensim.models.keyedvectors.Vocab at 0x1a22896208>,
#  '快速': <gensim.models.keyedvectors.Vocab at 0x1a22896240>,
#  '上': <gensim.models.keyedvectors.Vocab at 0x1a22896278>,
#  '期间': <gensim.models.keyedvectors.Vocab at 0x1a228962b0>,
#  '轻生': <gensim.models.keyedvectors.Vocab at 0x1a228962e8>,
#  '年头': <gensim.models.keyedvectors.Vocab at 0x1a22896320>,
#  '一辅警': <gensim.models.keyedvectors.Vocab at 0x1a22896358>,
#  '后': <gensim.models.keyedvectors.Vocab at 0x1a22896390>,
#  '赶紧': <gensim.models.keyedvectors.Vocab at 0x1a228963c8>,
#  '其': <gensim.models.keyedvectors.Vocab at 0x1a22896400>,
#  '披上': <gensim.models.keyedvectors.Vocab at 0x1a22896438>,
#  '黄衣': <gensim.models.keyedvectors.Vocab at 0x1a22896470>,
#  '并': <gensim.models.keyedvectors.Vocab at 0x1a228964a8>,
#  '一路': <gensim.models.keyedvectors.Vocab at 0x1a228964e0>,
#  '劝说': <gensim.models.keyedvectors.Vocab at 0x1a22896518>,
#  '她': <gensim.models.keyedvectors.Vocab at 0x1a22896550>,
#  '那么': <gensim.models.keyedvectors.Vocab at 0x1a22896588>,
#  '事发': <gensim.models.keyedvectors.Vocab at 0x1a228965c0>,
#  '时': <gensim.models.keyedvectors.Vocab at 0x1a228965f8>,
#  '到底': <gensim.models.keyedvectors.Vocab at 0x1a22896630>,
#  '都': <gensim.models.keyedvectors.Vocab at 0x1a22896668>,
#  '发生': <gensim.models.keyedvectors.Vocab at 0x1a228966a0>,
#  '些': <gensim.models.keyedvectors.Vocab at 0x1a228966d8>,
#  '什么': <gensim.models.keyedvectors.Vocab at 0x1a22896710>,
#  '呢': <gensim.models.keyedvectors.Vocab at 0x1a22896748>,
#  '？': <gensim.models.keyedvectors.Vocab at 0x1a22896780>,
#  '南': <gensim.models.keyedvectors.Vocab at 0x1a228967b8>,
#  '带': <gensim.models.keyedvectors.Vocab at 0x1a228967f0>,
#  '您': <gensim.models.keyedvectors.Vocab at 0x1a22896828>,
#  '一起': <gensim.models.keyedvectors.Vocab at 0x1a22896860>,
#  '还原': <gensim.models.keyedvectors.Vocab at 0x1a22896898>,
#  '现场': <gensim.models.keyedvectors.Vocab at 0x1a228968d0>,
#  '龙岗': <gensim.models.keyedvectors.Vocab at 0x1a22896908>,
#  '大队': <gensim.models.keyedvectors.Vocab at 0x1a22896940>,
#  '坂田': <gensim.models.keyedvectors.Vocab at 0x1a22896978>,
#  '中队': <gensim.models.keyedvectors.Vocab at 0x1a228969b0>,
#  '辅警': <gensim.models.keyedvectors.Vocab at 0x1a228969e8>,
#  '刘青': <gensim.models.keyedvectors.Vocab at 0x1a22896a20>,
#  '女生': <gensim.models.keyedvectors.Vocab at 0x1a22896a58>,
#  '一位': <gensim.models.keyedvectors.Vocab at 0x1a22896a90>,
#  '外表': <gensim.models.keyedvectors.Vocab at 0x1a22896ac8>,
#  '高大': <gensim.models.keyedvectors.Vocab at 0x1a22896b00>,
#  '帅气': <gensim.models.keyedvectors.Vocab at 0x1a22896b38>,
#  '说话': <gensim.models.keyedvectors.Vocab at 0x1a22896b70>,
#  '略带': <gensim.models.keyedvectors.Vocab at 0x1a22896ba8>,
#  '腼腆': <gensim.models.keyedvectors.Vocab at 0x1a22896be0>,
#  '90': <gensim.models.keyedvectors.Vocab at 0x1a22896c18>,
#  '青年': <gensim.models.keyedvectors.Vocab at 0x1a22896c50>,
#  '介绍': <gensim.models.keyedvectors.Vocab at 0x1a22896c88>,
#  '16': <gensim.models.keyedvectors.Vocab at 0x1a22896cc0>,
#  '早上': <gensim.models.keyedvectors.Vocab at 0x1a22896cf8>,
#  '7': <gensim.models.keyedvectors.Vocab at 0x1a22896d30>,
#  '36': <gensim.models.keyedvectors.Vocab at 0x1a22896d68>,
#  '分': <gensim.models.keyedvectors.Vocab at 0x1a22896da0>,
#  '他': <gensim.models.keyedvectors.Vocab at 0x1a22896dd8>,
#  '正在': <gensim.models.keyedvectors.Vocab at 0x1a22896e10>,
#  '环城': <gensim.models.keyedvectors.Vocab at 0x1a22896e48>,
#  '南路': <gensim.models.keyedvectors.Vocab at 0x1a22896e80>,
#  '附近': <gensim.models.keyedvectors.Vocab at 0x1a22896eb8>,
#  '值勤': <gensim.models.keyedvectors.Vocab at 0x1a22896ef0>,
#  '接到': <gensim.models.keyedvectors.Vocab at 0x1a22896f28>,
#  '机动车': <gensim.models.keyedvectors.Vocab at 0x1a22896f60>,
#  '危险': <gensim.models.keyedvectors.Vocab at 0x1a22896f98>,
#  '警情': <gensim.models.keyedvectors.Vocab at 0x1a22896fd0>,
#  '随后': <gensim.models.keyedvectors.Vocab at 0x1a22884048>,
#  '骑着': <gensim.models.keyedvectors.Vocab at 0x1a22884080>,
#  '铁骑': <gensim.models.keyedvectors.Vocab at 0x1a228840b8>,
#  '沿路': <gensim.models.keyedvectors.Vocab at 0x1a228840f0>,
#  '寻找': <gensim.models.keyedvectors.Vocab at 0x1a22884128>,
#  '大概': <gensim.models.keyedvectors.Vocab at 0x1a22884160>,
#  '花': <gensim.models.keyedvectors.Vocab at 0x1a22884198>,
#  '十多分钟': <gensim.models.keyedvectors.Vocab at 0x1a228841d0>,
#  '大道': <gensim.models.keyedvectors.Vocab at 0x1a22884208>,
#  '出口': <gensim.models.keyedvectors.Vocab at 0x1a22884240>,
#  '往': <gensim.models.keyedvectors.Vocab at 0x1a22884278>,
#  '方向': <gensim.models.keyedvectors.Vocab at 0x1a228842b0>,
#  '逆行': <gensim.models.keyedvectors.Vocab at 0x1a228842e8>,
#  '辅道': <gensim.models.keyedvectors.Vocab at 0x1a22884320>,
#  '该': <gensim.models.keyedvectors.Vocab at 0x1a22884358>,
#  '身上': <gensim.models.keyedvectors.Vocab at 0x1a22884390>,
#  '一丝不挂': <gensim.models.keyedvectors.Vocab at 0x1a228843c8>,
#  '地逆': <gensim.models.keyedvectors.Vocab at 0x1a22884400>,
#  '车流': <gensim.models.keyedvectors.Vocab at 0x1a22884438>,
#  '而行': <gensim.models.keyedvectors.Vocab at 0x1a22884470>,
#  '走时': <gensim.models.keyedvectors.Vocab at 0x1a228844a8>,
#  '停': <gensim.models.keyedvectors.Vocab at 0x1a228844e0>,
#  '坐': <gensim.models.keyedvectors.Vocab at 0x1a22884518>,
#  '躺': <gensim.models.keyedvectors.Vocab at 0x1a22884550>,
#  '险象环生': <gensim.models.keyedvectors.Vocab at 0x1a22884588>,
#  '刘青停': <gensim.models.keyedvectors.Vocab at 0x1a228845c0>,
#  '好': <gensim.models.keyedvectors.Vocab at 0x1a228845f8>,
#  '另外': <gensim.models.keyedvectors.Vocab at 0x1a22884630>,
#  '一名': <gensim.models.keyedvectors.Vocab at 0x1a22884668>,
#  '巡防': <gensim.models.keyedvectors.Vocab at 0x1a228846a0>,
#  '员': <gensim.models.keyedvectors.Vocab at 0x1a228846d8>,
#  '追': <gensim.models.keyedvectors.Vocab at 0x1a22884710>,
#  '上去': <gensim.models.keyedvectors.Vocab at 0x1a22884748>,
#  '情绪': <gensim.models.keyedvectors.Vocab at 0x1a22884780>,
#  '很': <gensim.models.keyedvectors.Vocab at 0x1a228847b8>,
#  '低落': <gensim.models.keyedvectors.Vocab at 0x1a228847f0>,
#  '话': <gensim.models.keyedvectors.Vocab at 0x1a22884828>,
#  '不': <gensim.models.keyedvectors.Vocab at 0x1a22884860>,
#  '多': <gensim.models.keyedvectors.Vocab at 0x1a22884898>,
#  '尝试': <gensim.models.keyedvectors.Vocab at 0x1a228848d0>,
#  '交流': <gensim.models.keyedvectors.Vocab at 0x1a22884908>,
#  '离开': <gensim.models.keyedvectors.Vocab at 0x1a22884940>,
#  '可': <gensim.models.keyedvectors.Vocab at 0x1a22884978>,
#  '愿意': <gensim.models.keyedvectors.Vocab at 0x1a228849b0>,
#  '接受': <gensim.models.keyedvectors.Vocab at 0x1a228849e8>,
#  '继续': <gensim.models.keyedvectors.Vocab at 0x1a22884a20>,
#  '缓慢': <gensim.models.keyedvectors.Vocab at 0x1a22884a58>,
#  '地往': <gensim.models.keyedvectors.Vocab at 0x1a22884a90>,
#  '快速路': <gensim.models.keyedvectors.Vocab at 0x1a22884ac8>,
#  '主干道': <gensim.models.keyedvectors.Vocab at 0x1a22884b00>,
#  '走': <gensim.models.keyedvectors.Vocab at 0x1a22884b38>,
#  '此时': <gensim.models.keyedvectors.Vocab at 0x1a22884b70>,
#  '路边': <gensim.models.keyedvectors.Vocab at 0x1a22884ba8>,
#  '聚集': <gensim.models.keyedvectors.Vocab at 0x1a22884be0>,
#  '市民': <gensim.models.keyedvectors.Vocab at 0x1a22884c18>,
#  '围观': <gensim.models.keyedvectors.Vocab at 0x1a22884c50>,
#  '为了': <gensim.models.keyedvectors.Vocab at 0x1a22884c88>,
#  '刺激': <gensim.models.keyedvectors.Vocab at 0x1a22884cc0>,
#  '一边': <gensim.models.keyedvectors.Vocab at 0x1a22884cf8>,
#  '盯': <gensim.models.keyedvectors.Vocab at 0x1a22884d30>,
#  '着': <gensim.models.keyedvectors.Vocab at 0x1a22884d68>,
#  '驱赶': <gensim.models.keyedvectors.Vocab at 0x1a22884da0>,
#  '群众': <gensim.models.keyedvectors.Vocab at 0x1a22884dd8>,
#  '从': <gensim.models.keyedvectors.Vocab at 0x1a22884e10>,
#  '警方': <gensim.models.keyedvectors.Vocab at 0x1a22884e48>,
#  '提供': <gensim.models.keyedvectors.Vocab at 0x1a22884e80>,
#  '一份': <gensim.models.keyedvectors.Vocab at 0x1a22884eb8>,
#  '视频': <gensim.models.keyedvectors.Vocab at 0x1a22884ef0>,
#  '了解': <gensim.models.keyedvectors.Vocab at 0x1a22884f28>,
#  '到': <gensim.models.keyedvectors.Vocab at 0x1a22884f60>,
#  '25': <gensim.models.keyedvectors.Vocab at 0x1a22884f98>,
#  '出现': <gensim.models.keyedvectors.Vocab at 0x1a22884fd0>,
#  '坂雪岗': <gensim.models.keyedvectors.Vocab at 0x1a2288a048>,
#  '监控': <gensim.models.keyedvectors.Vocab at 0x1a2288a080>,
#  '穿着': <gensim.models.keyedvectors.Vocab at 0x1a2288a0b8>,
#  '白色': <gensim.models.keyedvectors.Vocab at 0x1a2288a0f0>,
#  '内裤': <gensim.models.keyedvectors.Vocab at 0x1a2288a128>,
#  '沿着': <gensim.models.keyedvectors.Vocab at 0x1a2288a160>,
#  '当时': <gensim.models.keyedvectors.Vocab at 0x1a2288a198>,
#  '正值': <gensim.models.keyedvectors.Vocab at 0x1a2288a1d0>,
#  '上班': <gensim.models.keyedvectors.Vocab at 0x1a2288a208>,
#  '高峰期': <gensim.models.keyedvectors.Vocab at 0x1a2288a240>,
#  '十字路口': <gensim.models.keyedvectors.Vocab at 0x1a2288a278>,
#  '排起': <gensim.models.keyedvectors.Vocab at 0x1a2288a2b0>,
#  '长队': <gensim.models.keyedvectors.Vocab at 0x1a2288a2e8>,
#  '当': <gensim.models.keyedvectors.Vocab at 0x1a2288a320>,
#  '路上': <gensim.models.keyedvectors.Vocab at 0x1a2288a358>,
#  '纷纷': <gensim.models.keyedvectors.Vocab at 0x1a2288a390>,
#  '驻足': <gensim.models.keyedvectors.Vocab at 0x1a2288a3c8>,
#  '观望': <gensim.models.keyedvectors.Vocab at 0x1a2288a400>,
#  '不少': <gensim.models.keyedvectors.Vocab at 0x1a2288a438>,
#  '车辆': <gensim.models.keyedvectors.Vocab at 0x1a2288a470>,
#  '放慢': <gensim.models.keyedvectors.Vocab at 0x1a2288a4a8>,
#  '速度': <gensim.models.keyedvectors.Vocab at 0x1a2288a4e0>,
#  '但': <gensim.models.keyedvectors.Vocab at 0x1a2288a518>,
#  '停下': <gensim.models.keyedvectors.Vocab at 0x1a2288a550>,
#  '脚步': <gensim.models.keyedvectors.Vocab at 0x1a2288a588>,
#  '依然': <gensim.models.keyedvectors.Vocab at 0x1a2288a5c0>,
#  '行进': <gensim.models.keyedvectors.Vocab at 0x1a2288a5f8>,
#  '中间': <gensim.models.keyedvectors.Vocab at 0x1a2288a630>,
#  '一辆': <gensim.models.keyedvectors.Vocab at 0x1a2288a668>,
#  '货车': <gensim.models.keyedvectors.Vocab at 0x1a2288a6a0>,
#  '挡住': <gensim.models.keyedvectors.Vocab at 0x1a2288a6d8>,
#  '镜头': <gensim.models.keyedvectors.Vocab at 0x1a2288a710>,
#  '但是': <gensim.models.keyedvectors.Vocab at 0x1a2288a748>,
#  '再次出现': <gensim.models.keyedvectors.Vocab at 0x1a2288a780>,
#  '没': <gensim.models.keyedvectors.Vocab at 0x1a2288a7b8>,
#  '穿': <gensim.models.keyedvectors.Vocab at 0x1a2288a7f0>,
#  '全身': <gensim.models.keyedvectors.Vocab at 0x1a2288a828>,
#  '裸露': <gensim.models.keyedvectors.Vocab at 0x1a2288a860>,
#  '朝着': <gensim.models.keyedvectors.Vocab at 0x1a2288a898>,
#  '周围': <gensim.models.keyedvectors.Vocab at 0x1a2288a8d0>,
#  '没有': <gensim.models.keyedvectors.Vocab at 0x1a2288a908>,
#  '人': <gensim.models.keyedvectors.Vocab at 0x1a2288a940>,
#  '尾随': <gensim.models.keyedvectors.Vocab at 0x1a2288a978>,
#  '或者': <gensim.models.keyedvectors.Vocab at 0x1a2288a9b0>,
#  '上前': <gensim.models.keyedvectors.Vocab at 0x1a2288a9e8>,
#  '劝止': <gensim.models.keyedvectors.Vocab at 0x1a2288aa20>,
#  '大清早': <gensim.models.keyedvectors.Vocab at 0x1a2288aa58>,
#  '看到': <gensim.models.keyedvectors.Vocab at 0x1a2288aa90>,
#  '这样': <gensim.models.keyedvectors.Vocab at 0x1a2288aac8>,
#  '情况': <gensim.models.keyedvectors.Vocab at 0x1a2288ab00>,
#  '恐怕': <gensim.models.keyedvectors.Vocab at 0x1a2288ab38>,
#  '大家': <gensim.models.keyedvectors.Vocab at 0x1a2288ab70>,
#  '办法': <gensim.models.keyedvectors.Vocab at 0x1a2288aba8>,
#  '淡定': <gensim.models.keyedvectors.Vocab at 0x1a2288abe0>,
#  '面对': <gensim.models.keyedvectors.Vocab at 0x1a2288ac18>,
#  '这一': <gensim.models.keyedvectors.Vocab at 0x1a2288ac50>,
#  '表示': <gensim.models.keyedvectors.Vocab at 0x1a2288ac88>,
#  '根本': <gensim.models.keyedvectors.Vocab at 0x1a2288acc0>,
#  '不敢': <gensim.models.keyedvectors.Vocab at 0x1a2288acf8>,
#  '看': <gensim.models.keyedvectors.Vocab at 0x1a2288ad30>,
#  '心里': <gensim.models.keyedvectors.Vocab at 0x1a2288ad68>,
#  '挺': <gensim.models.keyedvectors.Vocab at 0x1a2288ada0>,
#  '别扭': <gensim.models.keyedvectors.Vocab at 0x1a2288add8>,
#  '感觉': <gensim.models.keyedvectors.Vocab at 0x1a2288ae10>,
#  '尴尬': <gensim.models.keyedvectors.Vocab at 0x1a2288ae48>,
#  '跟随': <gensim.models.keyedvectors.Vocab at 0x1a2288ae80>,
#  '作出': <gensim.models.keyedvectors.Vocab at 0x1a2288aeb8>,
#  '让': <gensim.models.keyedvectors.Vocab at 0x1a2288aef0>,
#  '意想不到': <gensim.models.keyedvectors.Vocab at 0x1a2288af28>,
#  '举动': <gensim.models.keyedvectors.Vocab at 0x1a2288af60>,
#  '突然': <gensim.models.keyedvectors.Vocab at 0x1a2288af98>,
#  '靠近': <gensim.models.keyedvectors.Vocab at 0x1a2288afd0>,
#  '护栏': <gensim.models.keyedvectors.Vocab at 0x1a24e56048>,
#  '上面': <gensim.models.keyedvectors.Vocab at 0x1a24e56080>,
#  '跳下去': <gensim.models.keyedvectors.Vocab at 0x1a24e560b8>,
#  '赶忙': <gensim.models.keyedvectors.Vocab at 0x1a24e560f0>,
#  '冲上去': <gensim.models.keyedvectors.Vocab at 0x1a24e56128>,
#  '拉住': <gensim.models.keyedvectors.Vocab at 0x1a24e56160>,
#  '手': <gensim.models.keyedvectors.Vocab at 0x1a24e56198>,
#  '控制': <gensim.models.keyedvectors.Vocab at 0x1a24e561d0>,
#  '住': <gensim.models.keyedvectors.Vocab at 0x1a24e56208>,
#  '远离': <gensim.models.keyedvectors.Vocab at 0x1a24e56240>,
#  '碍于': <gensim.models.keyedvectors.Vocab at 0x1a24e56278>,
#  '穿衣服': <gensim.models.keyedvectors.Vocab at 0x1a24e562b0>,
#  '刘青递': <gensim.models.keyedvectors.Vocab at 0x1a24e562e8>,
#  '衣服': <gensim.models.keyedvectors.Vocab at 0x1a24e56320>,
#  '把': <gensim.models.keyedvectors.Vocab at 0x1a24e56358>,
#  '扔': <gensim.models.keyedvectors.Vocab at 0x1a24e56390>,
#  '排水沟': <gensim.models.keyedvectors.Vocab at 0x1a24e563c8>,
#  '里': <gensim.models.keyedvectors.Vocab at 0x1a24e56400>,
#  '往前走': <gensim.models.keyedvectors.Vocab at 0x1a24e56438>,
#  '只能': <gensim.models.keyedvectors.Vocab at 0x1a24e56470>,
#  '紧紧': <gensim.models.keyedvectors.Vocab at 0x1a24e564a8>,
#  '拉': <gensim.models.keyedvectors.Vocab at 0x1a24e564e0>,
#  '一只': <gensim.models.keyedvectors.Vocab at 0x1a24e56518>,
#  '跟': <gensim.models.keyedvectors.Vocab at 0x1a24e56550>,
#  '后面': <gensim.models.keyedvectors.Vocab at 0x1a24e56588>,
#  '一路上': <gensim.models.keyedvectors.Vocab at 0x1a24e565c0>,
#  '耐心': <gensim.models.keyedvectors.Vocab at 0x1a24e565f8>,
#  '开导': <gensim.models.keyedvectors.Vocab at 0x1a24e56630>,
#  '安慰': <gensim.models.keyedvectors.Vocab at 0x1a24e56668>,
#  '听到': <gensim.models.keyedvectors.Vocab at 0x1a24e566a0>,
#  '不断': <gensim.models.keyedvectors.Vocab at 0x1a24e566d8>,
#  '重复': <gensim.models.keyedvectors.Vocab at 0x1a24e56710>,
#  '一句': <gensim.models.keyedvectors.Vocab at 0x1a24e56748>,
#  '要是': <gensim.models.keyedvectors.Vocab at 0x1a24e56780>,
#  '你': <gensim.models.keyedvectors.Vocab at 0x1a24e567b8>,
#  '遭遇': <gensim.models.keyedvectors.Vocab at 0x1a24e567f0>,
#  '我': <gensim.models.keyedvectors.Vocab at 0x1a24e56828>,
#  '事': <gensim.models.keyedvectors.Vocab at 0x1a24e56860>,
#  '会': <gensim.models.keyedvectors.Vocab at 0x1a24e56898>,
#  '不时': <gensim.models.keyedvectors.Vocab at 0x1a24e568d0>,
#  '试图': <gensim.models.keyedvectors.Vocab at 0x1a24e56908>,
#  '挣脱': <gensim.models.keyedvectors.Vocab at 0x1a24e56940>,
#  '手要': <gensim.models.keyedvectors.Vocab at 0x1a24e56978>,
#  '冲向': <gensim.models.keyedvectors.Vocab at 0x1a24e569b0>,
#  '往下跳': <gensim.models.keyedvectors.Vocab at 0x1a24e569e8>,
#  '就': <gensim.models.keyedvectors.Vocab at 0x1a24e56a20>,
#  '牵': <gensim.models.keyedvectors.Vocab at 0x1a24e56a58>,
#  '天': <gensim.models.keyedvectors.Vocab at 0x1a24e56a90>,
#  '下起': <gensim.models.keyedvectors.Vocab at 0x1a24e56ac8>,
#  '大暴雨': <gensim.models.keyedvectors.Vocab at 0x1a24e56b00>,
#  '雨大': <gensim.models.keyedvectors.Vocab at 0x1a24e56b38>,
#  '连': <gensim.models.keyedvectors.Vocab at 0x1a24e56b70>,
#  '眼睛': <gensim.models.keyedvectors.Vocab at 0x1a24e56ba8>,
#  '睁不开': <gensim.models.keyedvectors.Vocab at 0x1a24e56be0>,
#  '说': <gensim.models.keyedvectors.Vocab at 0x1a24e56c18>,
#  '瞬间': <gensim.models.keyedvectors.Vocab at 0x1a24e56c50>,
#  '雨': <gensim.models.keyedvectors.Vocab at 0x1a24e56c88>,
#  '透': <gensim.models.keyedvectors.Vocab at 0x1a24e56cc0>,
#  '帮助': <gensim.models.keyedvectors.Vocab at 0x1a24e56cf8>,
#  '冒': <gensim.models.keyedvectors.Vocab at 0x1a24e56d30>,
#  '大雨': <gensim.models.keyedvectors.Vocab at 0x1a24e56d68>,
#  '四十分钟': <gensim.models.keyedvectors.Vocab at 0x1a24e56da0>,
#  '吧': <gensim.models.keyedvectors.Vocab at 0x1a24e56dd8>,
#  '来说': <gensim.models.keyedvectors.Vocab at 0x1a24e56e10>,
#  '想': <gensim.models.keyedvectors.Vocab at 0x1a24e56e48>,
#  '回家': <gensim.models.keyedvectors.Vocab at 0x1a24e56e80>,
#  '然后': <gensim.models.keyedvectors.Vocab at 0x1a24e56eb8>,
#  '递过来': <gensim.models.keyedvectors.Vocab at 0x1a24e56ef0>,
#  '微博上': <gensim.models.keyedvectors.Vocab at 0x1a24e56f28>,
#  '照片': <gensim.models.keyedvectors.Vocab at 0x1a24e56f60>,
#  '披着': <gensim.models.keyedvectors.Vocab at 0x1a24e56f98>,
#  '小心翼翼': <gensim.models.keyedvectors.Vocab at 0x1a24e56fd0>,
#  '旁边': <gensim.models.keyedvectors.Vocab at 0x1a24e8c048>,
#  '场景': <gensim.models.keyedvectors.Vocab at 0x1a24e8c080>,
#  '南平': <gensim.models.keyedvectors.Vocab at 0x1a24e8c0b8>,
#  '下来': <gensim.models.keyedvectors.Vocab at 0x1a24e8c0f0>,
#  '带到': <gensim.models.keyedvectors.Vocab at 0x1a24e8c128>,
#  '派出所': <gensim.models.keyedvectors.Vocab at 0x1a24e8c160>,
#  '那': <gensim.models.keyedvectors.Vocab at 0x1a24e8c198>,
#  '姑娘': <gensim.models.keyedvectors.Vocab at 0x1a24e8c1d0>,
#  '什么样': <gensim.models.keyedvectors.Vocab at 0x1a24e8c208>,
#  '事情': <gensim.models.keyedvectors.Vocab at 0x1a24e8c240>,
#  '才': <gensim.models.keyedvectors.Vocab at 0x1a24e8c278>,
#  '据': <gensim.models.keyedvectors.Vocab at 0x1a24e8c2b0>,
#  '透露': <gensim.models.keyedvectors.Vocab at 0x1a24e8c2e8>,
#  '姓': <gensim.models.keyedvectors.Vocab at 0x1a24e8c320>,
#  '陈': <gensim.models.keyedvectors.Vocab at 0x1a24e8c358>,
#  '系': <gensim.models.keyedvectors.Vocab at 0x1a24e8c390>,
#  '湖北': <gensim.models.keyedvectors.Vocab at 0x1a24e8c3c8>,
#  '家属': <gensim.models.keyedvectors.Vocab at 0x1a24e8c400>,
#  '反映': <gensim.models.keyedvectors.Vocab at 0x1a24e8c438>,
#  '其有': <gensim.models.keyedvectors.Vocab at 0x1a24e8c470>,
#  '精神病': <gensim.models.keyedvectors.Vocab at 0x1a24e8c4a8>,
#  '史': <gensim.models.keyedvectors.Vocab at 0x1a24e8c4e0>,
#  '三天': <gensim.models.keyedvectors.Vocab at 0x1a24e8c518>,
#  '前': <gensim.models.keyedvectors.Vocab at 0x1a24e8c550>,
#  '陈某': <gensim.models.keyedvectors.Vocab at 0x1a24e8c588>,
#  '老家': <gensim.models.keyedvectors.Vocab at 0x1a24e8c5c0>,
#  '来': <gensim.models.keyedvectors.Vocab at 0x1a24e8c5f8>,
#  '受挫': <gensim.models.keyedvectors.Vocab at 0x1a24e8c630>,
#  '导致': <gensim.models.keyedvectors.Vocab at 0x1a24e8c668>,
#  '异常': <gensim.models.keyedvectors.Vocab at 0x1a24e8c6a0>,
#  '遂': <gensim.models.keyedvectors.Vocab at 0x1a24e8c6d8>,
#  '产生': <gensim.models.keyedvectors.Vocab at 0x1a24e8c710>,
#  '念头': <gensim.models.keyedvectors.Vocab at 0x1a24e8c748>,
#  '送往': <gensim.models.keyedvectors.Vocab at 0x1a24e8c780>,
#  '某': <gensim.models.keyedvectors.Vocab at 0x1a24e8c7b8>,
#  '医院': <gensim.models.keyedvectors.Vocab at 0x1a24e8c7f0>,
#  '治疗': <gensim.models.keyedvectors.Vocab at 0x1a24e8c828>,
#  '大大': <gensim.models.keyedvectors.Vocab at 0x1a24e8c860>,
#  '君': <gensim.models.keyedvectors.Vocab at 0x1a24e8c898>,
#  '希望': <gensim.models.keyedvectors.Vocab at 0x1a24e8c8d0>,
#  '早点': <gensim.models.keyedvectors.Vocab at 0x1a24e8c908>,
#  '康复': <gensim.models.keyedvectors.Vocab at 0x1a24e8c940>,
#  '其实': <gensim.models.keyedvectors.Vocab at 0x1a24e8c978>,
#  '真爱': <gensim.models.keyedvectors.Vocab at 0x1a24e8c9b0>,
#  '到来': <gensim.models.keyedvectors.Vocab at 0x1a24e8c9e8>,
#  '存在': <gensim.models.keyedvectors.Vocab at 0x1a24e8ca20>,
#  '年龄': <gensim.models.keyedvectors.Vocab at 0x1a24e8ca58>,
#  '限制': <gensim.models.keyedvectors.Vocab at 0x1a24e8ca90>,
#  '你们': <gensim.models.keyedvectors.Vocab at 0x1a24e8cac8>,
#  '因': <gensim.models.keyedvectors.Vocab at 0x1a24e8cb00>,
#  '善良': <gensim.models.keyedvectors.Vocab at 0x1a24e8cb38>,
#  '原因': <gensim.models.keyedvectors.Vocab at 0x1a24e8cb70>,
#  '一众': <gensim.models.keyedvectors.Vocab at 0x1a24e8cba8>,
#  '暖': <gensim.models.keyedvectors.Vocab at 0x1a24e8cbe0>,
#  '男点': <gensim.models.keyedvectors.Vocab at 0x1a24e8cc18>,
#  'ZAN': <gensim.models.keyedvectors.Vocab at 0x1a24e8cc50>,
#  '弓常': <gensim.models.keyedvectors.Vocab at 0x1a24e8cc88>,
#  'yan': <gensim.models.keyedvectors.Vocab at 0x1a24e8ccc0>,
#  '桦': <gensim.models.keyedvectors.Vocab at 0x1a24e8ccf8>,
#  '问': <gensim.models.keyedvectors.Vocab at 0x1a24e8cd30>,
#  '这个': <gensim.models.keyedvectors.Vocab at 0x1a24e8cd68>,
#  '哥哥': <gensim.models.keyedvectors.Vocab at 0x1a24e8cda0>,
#  '女票': <gensim.models.keyedvectors.Vocab at 0x1a24e8cdd8>,
#  '吗': <gensim.models.keyedvectors.Vocab at 0x1a24e8ce10>,
#  '原谅': <gensim.models.keyedvectors.Vocab at 0x1a24e8ce48>,
#  '一辈子': <gensim.models.keyedvectors.Vocab at 0x1a24e8ce80>,
#  '浪荡': <gensim.models.keyedvectors.Vocab at 0x1a24e8ceb8>,
#  '不羁': <gensim.models.keyedvectors.Vocab at 0x1a24e8cef0>,
#  '爱': <gensim.models.keyedvectors.Vocab at 0x1a24e8cf28>,
#  '萨摩耶': <gensim.models.keyedvectors.Vocab at 0x1a24e8cf60>,
#  '过不去': <gensim.models.keyedvectors.Vocab at 0x1a24e8cf98>,
#  '嘛': <gensim.models.keyedvectors.Vocab at 0x1a24e8cfd0>,
#  '想想': <gensim.models.keyedvectors.Vocab at 0x1a24e80048>,
#  '自己': <gensim.models.keyedvectors.Vocab at 0x1a24e80080>,
#  '家人': <gensim.models.keyedvectors.Vocab at 0x1a24e800b8>,
#  '同时': <gensim.models.keyedvectors.Vocab at 0x1a24e800f0>,
#  '感谢': <gensim.models.keyedvectors.Vocab at 0x1a24e80128>,
#  '蜀黍': <gensim.models.keyedvectors.Vocab at 0x1a24e80160>,
#  '火心': <gensim.models.keyedvectors.Vocab at 0x1a24e80198>,
#  '聆听': <gensim.models.keyedvectors.Vocab at 0x1a24e801d0>,
#  '心灵': <gensim.models.keyedvectors.Vocab at 0x1a24e80208>,
#  '点赞': <gensim.models.keyedvectors.Vocab at 0x1a24e80240>,
#  '中華云盾': <gensim.models.keyedvectors.Vocab at 0x1a24e80278>,
#  '警察': <gensim.models.keyedvectors.Vocab at 0x1a24e802b0>,
#  '就是': <gensim.models.keyedvectors.Vocab at 0x1a24e802e8>,
#  '需时': <gensim.models.keyedvectors.Vocab at 0x1a24e80320>,
#  '申出': <gensim.models.keyedvectors.Vocab at 0x1a24e80358>,
#  '援手': <gensim.models.keyedvectors.Vocab at 0x1a24e80390>,
#  'Tomchlee': <gensim.models.keyedvectors.Vocab at 0x1a24e803c8>,
#  '帅': <gensim.models.keyedvectors.Vocab at 0x1a24e80400>,
#  '！': <gensim.models.keyedvectors.Vocab at 0x1a24e80438>,
#  'SJ': <gensim.models.keyedvectors.Vocab at 0x1a24e80470>,
#  '李赫海': <gensim.models.keyedvectors.Vocab at 0x1a24e804a8>,
#  'i': <gensim.models.keyedvectors.Vocab at 0x1a24e804e0>,
#  '木有': <gensim.models.keyedvectors.Vocab at 0x1a24e80518>,
#  '男子': <gensim.models.keyedvectors.Vocab at 0x1a24e80550>,
#  '迷奸': <gensim.models.keyedvectors.Vocab at 0x1a24e80588>,
#  '拍': <gensim.models.keyedvectors.Vocab at 0x1a24e805c0>,
#  '418': <gensim.models.keyedvectors.Vocab at 0x1a24e805f8>,
#  '女方': <gensim.models.keyedvectors.Vocab at 0x1a24e80630>,
#  '20': <gensim.models.keyedvectors.Vocab at 0x1a24e80668>,
#  '50': <gensim.models.keyedvectors.Vocab at 0x1a24e806a0>,
#  '号': <gensim.models.keyedvectors.Vocab at 0x1a24e806d8>,
#  '上午': <gensim.models.keyedvectors.Vocab at 0x1a24e80710>,
#  '淮安市': <gensim.models.keyedvectors.Vocab at 0x1a24e80748>,
#  '涟水县': <gensim.models.keyedvectors.Vocab at 0x1a24e80780>,
#  '公安局': <gensim.models.keyedvectors.Vocab at 0x1a24e807b8>,
#  '刑警大队': <gensim.models.keyedvectors.Vocab at 0x1a24e807f0>,
#  '一个': <gensim.models.keyedvectors.Vocab at 0x1a24e80828>,
#  '奇怪': <gensim.models.keyedvectors.Vocab at 0x1a24e80860>,
#  '报警': <gensim.models.keyedvectors.Vocab at 0x1a24e80898>,
#  '电话': <gensim.models.keyedvectors.Vocab at 0x1a24e808d0>,
#  '言语': <gensim.models.keyedvectors.Vocab at 0x1a24e80908>,
#  '不清': <gensim.models.keyedvectors.Vocab at 0x1a24e80940>,
#  '声称': <gensim.models.keyedvectors.Vocab at 0x1a24e80978>,
#  '遭到': <gensim.models.keyedvectors.Vocab at 0x1a24e809b0>,
#  '侵害': <gensim.models.keyedvectors.Vocab at 0x1a24e809e8>,
#  '几个': <gensim.models.keyedvectors.Vocab at 0x1a24e80a20>,
#  '关键词': <gensim.models.keyedvectors.Vocab at 0x1a24e80a58>,
#  '令': <gensim.models.keyedvectors.Vocab at 0x1a24e80a90>,
#  '民警': <gensim.models.keyedvectors.Vocab at 0x1a24e80ac8>,
#  '紧张': <gensim.models.keyedvectors.Vocab at 0x1a24e80b00>,
#  '起来': <gensim.models.keyedvectors.Vocab at 0x1a24e80b38>,
#  '受到': <gensim.models.keyedvectors.Vocab at 0x1a24e80b70>,
#  'A股': <gensim.models.keyedvectors.Vocab at 0x1a24e80ba8>,
#  '纳入': <gensim.models.keyedvectors.Vocab at 0x1a24e80be0>,
#  'MSCI': <gensim.models.keyedvectors.Vocab at 0x1a24e80c18>,
#  '指数': <gensim.models.keyedvectors.Vocab at 0x1a24e80c50>,
#  '利好': <gensim.models.keyedvectors.Vocab at 0x1a24e80c88>,
#  '消息': <gensim.models.keyedvectors.Vocab at 0x1a24e80cc0>,
#  '市场': <gensim.models.keyedvectors.Vocab at 0x1a24e80cf8>,
#  '周三': <gensim.models.keyedvectors.Vocab at 0x1a24e80d30>,
#  '再度': <gensim.models.keyedvectors.Vocab at 0x1a24e80d68>,
#  '上演': <gensim.models.keyedvectors.Vocab at 0x1a24e80da0>,
#  '龙马': <gensim.models.keyedvectors.Vocab at 0x1a24e80dd8>,
#  '行情': <gensim.models.keyedvectors.Vocab at 0x1a24e80e10>,
#  '周四': <gensim.models.keyedvectors.Vocab at 0x1a24e80e48>,
#  '金融股': <gensim.models.keyedvectors.Vocab at 0x1a24e80e80>,
#  '白马股': <gensim.models.keyedvectors.Vocab at 0x1a24e80eb8>,
#  '表现': <gensim.models.keyedvectors.Vocab at 0x1a24e80ef0>,
#  '喜人': <gensim.models.keyedvectors.Vocab at 0x1a24e80f28>,
#  '尾盘': <gensim.models.keyedvectors.Vocab at 0x1a24e80f60>,
#  '跳水': <gensim.models.keyedvectors.Vocab at 0x1a24e80f98>,
#  '之后': <gensim.models.keyedvectors.Vocab at 0x1a24e80fd0>,
#  '仅': <gensim.models.keyedvectors.Vocab at 0x1a24e68048>,
#  '金融': <gensim.models.keyedvectors.Vocab at 0x1a24e68080>,
#  '板块': <gensim.models.keyedvectors.Vocab at 0x1a24e680b8>,
#  '仍': <gensim.models.keyedvectors.Vocab at 0x1a24e680f0>,
#  '维系': <gensim.models.keyedvectors.Vocab at 0x1a24e68128>,
#  '红盘': <gensim.models.keyedvectors.Vocab at 0x1a24e68160>,
#  '状态': <gensim.models.keyedvectors.Vocab at 0x1a24e68198>,
#  '分析': <gensim.models.keyedvectors.Vocab at 0x1a24e681d0>,
#  '人士': <gensim.models.keyedvectors.Vocab at 0x1a24e68208>,
#  '认为': <gensim.models.keyedvectors.Vocab at 0x1a24e68240>,
#  '受益': <gensim.models.keyedvectors.Vocab at 0x1a24e68278>,
#  '于': <gensim.models.keyedvectors.Vocab at 0x1a24e682b0>,
#  '低': <gensim.models.keyedvectors.Vocab at 0x1a24e682e8>,
#  '估值': <gensim.models.keyedvectors.Vocab at 0x1a24e68320>,
#  '重获': <gensim.models.keyedvectors.Vocab at 0x1a24e68358>,
#  '资金': <gensim.models.keyedvectors.Vocab at 0x1a24e68390>,
#  '青睐': <gensim.models.keyedvectors.Vocab at 0x1a24e683c8>,
#  '存量': <gensim.models.keyedvectors.Vocab at 0x1a24e68400>,
#  '博弈': <gensim.models.keyedvectors.Vocab at 0x1a24e68438>,
#  '格局': <gensim.models.keyedvectors.Vocab at 0x1a24e68470>,
#  '下': <gensim.models.keyedvectors.Vocab at 0x1a24e684a8>,
#  '风格': <gensim.models.keyedvectors.Vocab at 0x1a24e684e0>,
#  '交替': <gensim.models.keyedvectors.Vocab at 0x1a24e68518>,
#  '震荡': <gensim.models.keyedvectors.Vocab at 0x1a24e68550>,
#  '料': <gensim.models.keyedvectors.Vocab at 0x1a24e68588>,
#  '延续': <gensim.models.keyedvectors.Vocab at 0x1a24e685c0>,
#  '流动性': <gensim.models.keyedvectors.Vocab at 0x1a24e685f8>,
#  '改善': <gensim.models.keyedvectors.Vocab at 0x1a24e68630>,
#  '经济': <gensim.models.keyedvectors.Vocab at 0x1a24e68668>,
#  '悲观': <gensim.models.keyedvectors.Vocab at 0x1a24e686a0>,
#  '预期': <gensim.models.keyedvectors.Vocab at 0x1a24e686d8>,
#  '修正': <gensim.models.keyedvectors.Vocab at 0x1a24e68710>,
#  '有助于': <gensim.models.keyedvectors.Vocab at 0x1a24e68748>,
#  '支撑': <gensim.models.keyedvectors.Vocab at 0x1a24e68780>,
#  '继而': <gensim.models.keyedvectors.Vocab at 0x1a24e687b8>,
#  '大盘': <gensim.models.keyedvectors.Vocab at 0x1a24e687f0>,
#  '逐步': <gensim.models.keyedvectors.Vocab at 0x1a24e68828>,
#  '向': <gensim.models.keyedvectors.Vocab at 0x1a24e68860>,
#  '九': <gensim.models.keyedvectors.Vocab at 0x1a24e68898>,
#  '再现': <gensim.models.keyedvectors.Vocab at 0x1a24e688d0>,
#  '未能': <gensim.models.keyedvectors.Vocab at 0x1a24e68908>,
#  '上行': <gensim.models.keyedvectors.Vocab at 0x1a24e68940>,
#  '态势': <gensim.models.keyedvectors.Vocab at 0x1a24e68978>,
#  '两市': <gensim.models.keyedvectors.Vocab at 0x1a24e689b0>,
#  '成交': <gensim.models.keyedvectors.Vocab at 0x1a24e689e8>,
#  '小幅': <gensim.models.keyedvectors.Vocab at 0x1a24e68a20>,
#  '放量': <gensim.models.keyedvectors.Vocab at 0x1a24e68a58>,
#  '29': <gensim.models.keyedvectors.Vocab at 0x1a24e68a90>,
#  '中信': <gensim.models.keyedvectors.Vocab at 0x1a24e68ac8>,
#  '一级': <gensim.models.keyedvectors.Vocab at 0x1a24e68b00>,
#  '行业': <gensim.models.keyedvectors.Vocab at 0x1a24e68b38>,
#  '收盘': <gensim.models.keyedvectors.Vocab at 0x1a24e68b70>,
#  '银行': <gensim.models.keyedvectors.Vocab at 0x1a24e68ba8>,
#  '非银行': <gensim.models.keyedvectors.Vocab at 0x1a24e68be0>,
#  '两个': <gensim.models.keyedvectors.Vocab at 0x1a24e68c18>,
#  '收红': <gensim.models.keyedvectors.Vocab at 0x1a24e68c50>,
#  '分别': <gensim.models.keyedvectors.Vocab at 0x1a24e68c88>,
#  '上涨': <gensim.models.keyedvectors.Vocab at 0x1a24e68cc0>,
#  '1.80': <gensim.models.keyedvectors.Vocab at 0x1a24e68cf8>,
#  '0.20': <gensim.models.keyedvectors.Vocab at 0x1a24e68d30>,
#  '二级': <gensim.models.keyedvectors.Vocab at 0x1a24e68d68>,
#  '来看': <gensim.models.keyedvectors.Vocab at 0x1a24e68da0>,
#  '股份制': <gensim.models.keyedvectors.Vocab at 0x1a24e68dd8>,
#  '城商行': <gensim.models.keyedvectors.Vocab at 0x1a24e68e10>,
#  '涨幅': <gensim.models.keyedvectors.Vocab at 0x1a24e68e48>,
#  '最高': <gensim.models.keyedvectors.Vocab at 0x1a24e68e80>,
#  '达到': <gensim.models.keyedvectors.Vocab at 0x1a24e68eb8>,
#  '2.22': <gensim.models.keyedvectors.Vocab at 0x1a24e68ef0>,
#  '国有银行': <gensim.models.keyedvectors.Vocab at 0x1a24e68f28>,
#  '0.82': <gensim.models.keyedvectors.Vocab at 0x1a24e68f60>,
#  '信托': <gensim.models.keyedvectors.Vocab at 0x1a24e68f98>,
#  '及其': <gensim.models.keyedvectors.Vocab at 0x1a24e68fd0>,
#  '0.64': <gensim.models.keyedvectors.Vocab at 0x1a24e5c048>,
#  '保险': <gensim.models.keyedvectors.Vocab at 0x1a24e5c080>,
#  '0.34': <gensim.models.keyedvectors.Vocab at 0x1a24e5c0b8>,
#  '证券': <gensim.models.keyedvectors.Vocab at 0x1a24e5c0f0>,
#  '0.06': <gensim.models.keyedvectors.Vocab at 0x1a24e5c128>,
#  '成分股': <gensim.models.keyedvectors.Vocab at 0x1a24e5c160>,
#  '共有': <gensim.models.keyedvectors.Vocab at 0x1a24e5c198>,
#  '21': <gensim.models.keyedvectors.Vocab at 0x1a24e5c1d0>,
#  '其中': <gensim.models.keyedvectors.Vocab at 0x1a24e5c208>,
#  '招商银行': <gensim.models.keyedvectors.Vocab at 0x1a24e5c240>,
#  '最大': <gensim.models.keyedvectors.Vocab at 0x1a24e5c278>,
#  '6.66': <gensim.models.keyedvectors.Vocab at 0x1a24e5c2b0>,
#  '贵阳': <gensim.models.keyedvectors.Vocab at 0x1a24e5c2e8>,
#  '3.65': <gensim.models.keyedvectors.Vocab at 0x1a24e5c320>,
#  '上海银行': <gensim.models.keyedvectors.Vocab at 0x1a24e5c358>,
#  '华夏银行': <gensim.models.keyedvectors.Vocab at 0x1a24e5c390>,
#  '浦发银行': <gensim.models.keyedvectors.Vocab at 0x1a24e5c3c8>,
#  '兴业银行': <gensim.models.keyedvectors.Vocab at 0x1a24e5c400>,
#  '超过': <gensim.models.keyedvectors.Vocab at 0x1a24e5c438>,
#  '1.50': <gensim.models.keyedvectors.Vocab at 0x1a24e5c470>,
#  '共': <gensim.models.keyedvectors.Vocab at 0x1a24e5c4a8>,
#  '17': <gensim.models.keyedvectors.Vocab at 0x1a24e5c4e0>,
#  '个股': <gensim.models.keyedvectors.Vocab at 0x1a24e5c518>,
#  '安信': <gensim.models.keyedvectors.Vocab at 0x1a24e5c550>,
#  '中国': <gensim.models.keyedvectors.Vocab at 0x1a24e5c588>,
#  '太保': <gensim.models.keyedvectors.Vocab at 0x1a24e5c5c0>,
#  '居前': <gensim.models.keyedvectors.Vocab at 0x1a24e5c5f8>,
#  '两名': <gensim.models.keyedvectors.Vocab at 0x1a24e5c630>,
#  '4.57': <gensim.models.keyedvectors.Vocab at 0x1a24e5c668>,
#  '3.04': <gensim.models.keyedvectors.Vocab at 0x1a24e5c6a0>,
#  '西水股份': <gensim.models.keyedvectors.Vocab at 0x1a24e5c6d8>,
#  '华安': <gensim.models.keyedvectors.Vocab at 0x1a24e5c710>,
#  '人寿': <gensim.models.keyedvectors.Vocab at 0x1a24e5c748>,
#  '新华': <gensim.models.keyedvectors.Vocab at 0x1a24e5c780>,
#  '2': <gensim.models.keyedvectors.Vocab at 0x1a24e5c7b8>,
#  '相对而言': <gensim.models.keyedvectors.Vocab at 0x1a24e5c7f0>,
#  '券商': <gensim.models.keyedvectors.Vocab at 0x1a24e5c828>,
#  '股多': <gensim.models.keyedvectors.Vocab at 0x1a24e5c860>,
#  '下跌': <gensim.models.keyedvectors.Vocab at 0x1a24e5c898>,
#  '近期': <gensim.models.keyedvectors.Vocab at 0x1a24e5c8d0>,
#  '对': <gensim.models.keyedvectors.Vocab at 0x1a24e5c908>,
#  '消息面': <gensim.models.keyedvectors.Vocab at 0x1a24e5c940>,
#  '宣布': <gensim.models.keyedvectors.Vocab at 0x1a24e5c978>,
#  '2018': <gensim.models.keyedvectors.Vocab at 0x1a24e5c9b0>,
#  '年': <gensim.models.keyedvectors.Vocab at 0x1a24e5c9e8>,
#  '新兴': <gensim.models.keyedvectors.Vocab at 0x1a24e5ca20>,
#  '占': <gensim.models.keyedvectors.Vocab at 0x1a24e5ca58>,
#  '群体': <gensim.models.keyedvectors.Vocab at 0x1a24e5ca90>,
#  '国金': <gensim.models.keyedvectors.Vocab at 0x1a24e5cac8>,
#  '李立峰': <gensim.models.keyedvectors.Vocab at 0x1a24e5cb00>,
#  '团队': <gensim.models.keyedvectors.Vocab at 0x1a24e5cb38>,
#  '指出': <gensim.models.keyedvectors.Vocab at 0x1a24e5cb70>,
#  '最新': <gensim.models.keyedvectors.Vocab at 0x1a24e5cba8>,
#  '包含': <gensim.models.keyedvectors.Vocab at 0x1a24e5cbe0>,
#  '222': <gensim.models.keyedvectors.Vocab at 0x1a24e5cc18>,
#  '剔除': <gensim.models.keyedvectors.Vocab at 0x1a24e5cc50>,
#  '中等': <gensim.models.keyedvectors.Vocab at 0x1a24e5cc88>,
#  '市值': <gensim.models.keyedvectors.Vocab at 0x1a24e5ccc0>,
#  '非': <gensim.models.keyedvectors.Vocab at 0x1a24e5ccf8>,
#  '互联互通': <gensim.models.keyedvectors.Vocab at 0x1a24e5cd30>,
#  '交易': <gensim.models.keyedvectors.Vocab at 0x1a24e5cd68>,
#  '股票': <gensim.models.keyedvectors.Vocab at 0x1a24e5cda0>,
#  '以及': <gensim.models.keyedvectors.Vocab at 0x1a24e5cdd8>,
#  '停牌': <gensim.models.keyedvectors.Vocab at 0x1a24e5ce10>,
#  '标的': <gensim.models.keyedvectors.Vocab at 0x1a24e5ce48>,
#  '由于': <gensim.models.keyedvectors.Vocab at 0x1a24e5ce80>,
#  '很多': <gensim.models.keyedvectors.Vocab at 0x1a24e5ceb8>,
#  'A': <gensim.models.keyedvectors.Vocab at 0x1a24e5cef0>,
#  'H股': <gensim.models.keyedvectors.Vocab at 0x1a24e5cf28>,
#  'EM': <gensim.models.keyedvectors.Vocab at 0x1a24e5cf60>,
#  '权重': <gensim.models.keyedvectors.Vocab at 0x1a24e5cf98>,
#  '由': <gensim.models.keyedvectors.Vocab at 0x1a24e5cfd0>,
#  '0.5': <gensim.models.keyedvectors.Vocab at 0x1a24bf7048>,
#  '上升': <gensim.models.keyedvectors.Vocab at 0x1a24bf7080>,
#  '0.73': <gensim.models.keyedvectors.Vocab at 0x1a24bf70b8>,
#  '40.11': <gensim.models.keyedvectors.Vocab at 0x1a24bf70f0>,
#  '泛': <gensim.models.keyedvectors.Vocab at 0x1a24bf7128>,
#  '消费': <gensim.models.keyedvectors.Vocab at 0x1a24bf7160>,
#  '次之': <gensim.models.keyedvectors.Vocab at 0x1a24bf7198>,
#  '24.26': <gensim.models.keyedvectors.Vocab at 0x1a24bf71d0>,
#  '涵盖': <gensim.models.keyedvectors.Vocab at 0x1a24bf7208>,
#  '大部分': <gensim.models.keyedvectors.Vocab at 0x1a24bf7240>,
#  '权重股': <gensim.models.keyedvectors.Vocab at 0x1a24bf7278>,
#  '动态': <gensim.models.keyedvectors.Vocab at 0x1a24bf72b0>,
#  '加入': <gensim.models.keyedvectors.Vocab at 0x1a24bf72e8>,
#  '指': <gensim.models.keyedvectors.Vocab at 0x1a24bf7320>,
#  '比高': <gensim.models.keyedvectors.Vocab at 0x1a24bf7358>,
#  '金融公司': <gensim.models.keyedvectors.Vocab at 0x1a24bf7390>,
#  '增加': <gensim.models.keyedvectors.Vocab at 0x1a24bf73c8>,
#  '近一半': <gensim.models.keyedvectors.Vocab at 0x1a24bf7400>,
#  '其他': <gensim.models.keyedvectors.Vocab at 0x1a24bf7438>,
#  '稀释': <gensim.models.keyedvectors.Vocab at 0x1a24bf7470>,
#  '尽管': <gensim.models.keyedvectors.Vocab at 0x1a24bf74a8>,
#  '事件': <gensim.models.keyedvectors.Vocab at 0x1a24bf74e0>,
#  '短期': <gensim.models.keyedvectors.Vocab at 0x1a24bf7518>,
#  '有所': <gensim.models.keyedvectors.Vocab at 0x1a24bf7550>,
#  '提振': <gensim.models.keyedvectors.Vocab at 0x1a24bf7588>,
#  '中长期': <gensim.models.keyedvectors.Vocab at 0x1a24bf75c0>,
#  '海外': <gensim.models.keyedvectors.Vocab at 0x1a24bf75f8>,
#  '增量': <gensim.models.keyedvectors.Vocab at 0x1a24bf7630>,
#  '升温': <gensim.models.keyedvectors.Vocab at 0x1a24bf7668>,
#  '短期内': <gensim.models.keyedvectors.Vocab at 0x1a24bf76a0>,
#  '尚': <gensim.models.keyedvectors.Vocab at 0x1a24bf76d8>,
#  '不能': <gensim.models.keyedvectors.Vocab at 0x1a24bf7710>,
#  '有效': <gensim.models.keyedvectors.Vocab at 0x1a24bf7748>,
#  '放大': <gensim.models.keyedvectors.Vocab at 0x1a24bf7780>,
#  '独': <gensim.models.keyedvectors.Vocab at 0x1a24bf77b8>,
#  '乐乐': <gensim.models.keyedvectors.Vocab at 0x1a24bf77f0>,
#  '情景': <gensim.models.keyedvectors.Vocab at 0x1a24bf7828>,
#  '难以': <gensim.models.keyedvectors.Vocab at 0x1a24bf7860>,
#  '持续': <gensim.models.keyedvectors.Vocab at 0x1a24bf7898>,
#  '难': <gensim.models.keyedvectors.Vocab at 0x1a24bf78d0>,
#  '改变': <gensim.models.keyedvectors.Vocab at 0x1a24bf7908>,
#  '光大': <gensim.models.keyedvectors.Vocab at 0x1a24bf7940>,
#  '并未': <gensim.models.keyedvectors.Vocab at 0x1a24bf7978>,
#  '引起': <gensim.models.keyedvectors.Vocab at 0x1a24bf79b0>,
#  '太大': <gensim.models.keyedvectors.Vocab at 0x1a24bf79e8>,
#  '热情': <gensim.models.keyedvectors.Vocab at 0x1a24bf7a20>,
#  '成交量': <gensim.models.keyedvectors.Vocab at 0x1a24bf7a58>,
#  '较为': <gensim.models.keyedvectors.Vocab at 0x1a24bf7a90>,
#  '平淡': <gensim.models.keyedvectors.Vocab at 0x1a24bf7ac8>,
#  '较大': <gensim.models.keyedvectors.Vocab at 0x1a24bf7b00>,
#  '变化': <gensim.models.keyedvectors.Vocab at 0x1a24bf7b38>,
#  '成长': <gensim.models.keyedvectors.Vocab at 0x1a24bf7b70>,
#  '股': <gensim.models.keyedvectors.Vocab at 0x1a24bf7ba8>,
#  '题材股': <gensim.models.keyedvectors.Vocab at 0x1a24bf7be0>,
#  '全天': <gensim.models.keyedvectors.Vocab at 0x1a24bf7c18>,
#  '低迷': <gensim.models.keyedvectors.Vocab at 0x1a24bf7c50>,
#  '表明': <gensim.models.keyedvectors.Vocab at 0x1a24bf7c88>,
#  '很少': <gensim.models.keyedvectors.Vocab at 0x1a24bf7cc0>,
#  '不同': <gensim.models.keyedvectors.Vocab at 0x1a24bf7cf8>,
#  '之间': <gensim.models.keyedvectors.Vocab at 0x1a24bf7d30>,
#  '腾挪': <gensim.models.keyedvectors.Vocab at 0x1a24bf7d68>,
#  '跷跷板': <gensim.models.keyedvectors.Vocab at 0x1a24bf7da0>,
#  '使得': <gensim.models.keyedvectors.Vocab at 0x1a24bf7dd8>,
#  '难有': <gensim.models.keyedvectors.Vocab at 0x1a24bf7e10>,
#  '突破': <gensim.models.keyedvectors.Vocab at 0x1a24bf7e48>,
#  '中期': <gensim.models.keyedvectors.Vocab at 0x1a24bf7e80>,
#  '依旧': <gensim.models.keyedvectors.Vocab at 0x1a24bf7eb8>,
#  '偏空': <gensim.models.keyedvectors.Vocab at 0x1a24bf7ef0>,
#  '维持': <gensim.models.keyedvectors.Vocab at 0x1a24bf7f28>,
#  '虽然': <gensim.models.keyedvectors.Vocab at 0x1a24bf7f60>,
#  '至今': <gensim.models.keyedvectors.Vocab at 0x1a24bf7f98>,
#  '夏普': <gensim.models.keyedvectors.Vocab at 0x1a24bf7fd0>,
#  '智能手机': <gensim.models.keyedvectors.Vocab at 0x1a24c0e048>,
#  '无法': <gensim.models.keyedvectors.Vocab at 0x1a24c0e080>,
#  '排得': <gensim.models.keyedvectors.Vocab at 0x1a24c0e0b8>,
#  '完全': <gensim.models.keyedvectors.Vocab at 0x1a24c0e0f0>,
#  '没落': <gensim.models.keyedvectors.Vocab at 0x1a24c0e128>,
#  '2013': <gensim.models.keyedvectors.Vocab at 0x1a24c0e160>,
#  '退出': <gensim.models.keyedvectors.Vocab at 0x1a24c0e198>,
#  '3': <gensim.models.keyedvectors.Vocab at 0x1a24c0e1d0>,
#  '月份': <gensim.models.keyedvectors.Vocab at 0x1a24c0e208>,
#  '官方': <gensim.models.keyedvectors.Vocab at 0x1a24c0e240>,
#  '回归': <gensim.models.keyedvectors.Vocab at 0x1a24c0e278>,
#  '预示': <gensim.models.keyedvectors.Vocab at 0x1a24c0e2b0>,
#  '很快': <gensim.models.keyedvectors.Vocab at 0x1a24c0e2e8>,
#  '新机': <gensim.models.keyedvectors.Vocab at 0x1a24c0e320>,
#  '登场': <gensim.models.keyedvectors.Vocab at 0x1a24c0e358>,
#  '第一款': <gensim.models.keyedvectors.Vocab at 0x1a24c0e390>,
#  '登陆': <gensim.models.keyedvectors.Vocab at 0x1a24c0e3c8>,
#  '又': <gensim.models.keyedvectors.Vocab at 0x1a24c0e400>,
#  '怎么样': <gensim.models.keyedvectors.Vocab at 0x1a24c0e438>,
#  '近日': <gensim.models.keyedvectors.Vocab at 0x1a24c0e470>,
#  '型号': <gensim.models.keyedvectors.Vocab at 0x1a24c0e4a8>,
#  'FS8016': <gensim.models.keyedvectors.Vocab at 0x1a24c0e4e0>,
#  '神秘': <gensim.models.keyedvectors.Vocab at 0x1a24c0e518>,
#  '悄然': <gensim.models.keyedvectors.Vocab at 0x1a24c0e550>,
#  'GeekBench': <gensim.models.keyedvectors.Vocab at 0x1a24c0e588>,
#  '分库': <gensim.models.keyedvectors.Vocab at 0x1a24c0e5c0>,
#  '相关': <gensim.models.keyedvectors.Vocab at 0x1a24c0e5f8>,
#  '机子': <gensim.models.keyedvectors.Vocab at 0x1a24c0e630>,
#  '并非': <gensim.models.keyedvectors.Vocab at 0x1a24c0e668>,
#  '定位': <gensim.models.keyedvectors.Vocab at 0x1a24c0e6a0>,
#  '所': <gensim.models.keyedvectors.Vocab at 0x1a24c0e6d8>,
#  '660': <gensim.models.keyedvectors.Vocab at 0x1a24c0e710>,
#  '配备': <gensim.models.keyedvectors.Vocab at 0x1a24c0e748>,
#  '4GB': <gensim.models.keyedvectors.Vocab at 0x1a24c0e780>,
#  '内存': <gensim.models.keyedvectors.Vocab at 0x1a24c0e7b8>,
#  '最受': <gensim.models.keyedvectors.Vocab at 0x1a24c0e7f0>,
#  '瞩目': <gensim.models.keyedvectors.Vocab at 0x1a24c0e828>,
#  '芯片': <gensim.models.keyedvectors.Vocab at 0x1a24c0e860>,
#  '之一': <gensim.models.keyedvectors.Vocab at 0x1a24c0e898>,
#  '采用': <gensim.models.keyedvectors.Vocab at 0x1a24c0e8d0>,
#  '14': <gensim.models.keyedvectors.Vocab at 0x1a24c0e908>,
#  '纳米': <gensim.models.keyedvectors.Vocab at 0x1a24c0e940>,
#  '工艺': <gensim.models.keyedvectors.Vocab at 0x1a24c0e978>,
#  '八个': <gensim.models.keyedvectors.Vocab at 0x1a24c0e9b0>,
#  'Kryo': <gensim.models.keyedvectors.Vocab at 0x1a24c0e9e8>,
#  '260': <gensim.models.keyedvectors.Vocab at 0x1a24c0ea20>,
#  '设计': <gensim.models.keyedvectors.Vocab at 0x1a24c0ea58>,
#  'Adreno': <gensim.models.keyedvectors.Vocab at 0x1a24c0ea90>,
#  '512': <gensim.models.keyedvectors.Vocab at 0x1a24c0eac8>,
#  'X12': <gensim.models.keyedvectors.Vocab at 0x1a24c0eb00>,
#  'LTE': <gensim.models.keyedvectors.Vocab at 0x1a24c0eb38>,
#  '调制解调器': <gensim.models.keyedvectors.Vocab at 0x1a24c0eb70>,
#  '当前': <gensim.models.keyedvectors.Vocab at 0x1a24c0eba8>,
#  '市面上': <gensim.models.keyedvectors.Vocab at 0x1a24c0ebe0>,
#  '只有': <gensim.models.keyedvectors.Vocab at 0x1a24c0ec18>,
#  '上市': <gensim.models.keyedvectors.Vocab at 0x1a24c0ec50>,
#  '销售': <gensim.models.keyedvectors.Vocab at 0x1a24c0ec88>,
#  'OPPO': <gensim.models.keyedvectors.Vocab at 0x1a24c0ecc0>,
#  'R11': <gensim.models.keyedvectors.Vocab at 0x1a24c0ecf8>,
#  '核新能': <gensim.models.keyedvectors.Vocab at 0x1a24c0ed30>,
#  '820': <gensim.models.keyedvectors.Vocab at 0x1a24c0ed68>,
#  '强': <gensim.models.keyedvectors.Vocab at 0x1a24c0eda0>,
#  '单核': <gensim.models.keyedvectors.Vocab at 0x1a24c0edd8>,
#  '改进': <gensim.models.keyedvectors.Vocab at 0x1a24c0ee10>,
#  '明显': <gensim.models.keyedvectors.Vocab at 0x1a24c0ee48>,
#  '所以': <gensim.models.keyedvectors.Vocab at 0x1a24c0ee80>,
#  '放在': <gensim.models.keyedvectors.Vocab at 0x1a24c0eeb8>,
#  '变成': <gensim.models.keyedvectors.Vocab at 0x1a24c0eef0>,
#  '高端': <gensim.models.keyedvectors.Vocab at 0x1a24c0ef28>,
#  '机': <gensim.models.keyedvectors.Vocab at 0x1a24c0ef60>,
#  '不过': <gensim.models.keyedvectors.Vocab at 0x1a24c0ef98>,
#  '签署': <gensim.models.keyedvectors.Vocab at 0x1a24c0efd0>,
#  '排他性': <gensim.models.keyedvectors.Vocab at 0x1a24c03048>,
#  '协议': <gensim.models.keyedvectors.Vocab at 0x1a24c03080>,
#  ...}

# %% [markdown]
# ## 2. NER  And Dependency Parsing
# + 区分出人名（person），组织机构名（organization）和地点（location）
# + 哈工大 LTP：https://stanfordnlp.github.io/CoreNLP/
# + Stanford CoreNLP：􏱋􏲓􏱔􏲒􏲤􏲘􏲦􏰓 􏲘􏲦􏰭􏱕􏱙􏱗􏰀https://stanfordnlp.github.io/CoreNLP/
